# %% [markdown]
# # Projeto de PE

# %% [markdown]
# #### Nota: Corre o seguinte com kernel de R

# %%
x<-matrix(1:9, 3)
x
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9
